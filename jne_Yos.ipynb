# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
import os                                   # Import library OS 
os.getcwd()                                 # Get the current working directory

# Cara 1:Change the current working directory
os.chdir('C:\\Users\\user\\Desktop\\Py_JNE\\data\\CS')  

# Cara 2:Change the current working directory
os.chdir('C:/Users/user/Desktop/Py_JNE/data/CS')

# %%
csa = pd.read_excel('RiskRegister.xlsx',sheet_name="CSA",skiprows=1,usecols='B:O')
csa
# Out:
#                      Departemen  Source Data Process  \
# 0          Warehouse Department   RG/WHD-001/II/2020
# 1          Warehouse Department  RG/WHD-002/III/2020
# 2          Warehouse Department   RG/WHD-003/II/2020
# 3          Warehouse Department   RG/WHD-004/II/2020
# 4          Warehouse Department   RG/WHD-005/II/2020
# ...                         ...                  ...
# 3174  Media Relation Department  RG/MDR-001/III/2020
# 3175  Media Relation Department  RG/MDR-001/III/2020
# 3176  Media Relation Department  RG/MDR-002/III/2020
# 3177  Media Relation Department  RG/MDR-002/III/2020
# 3178  Media Relation Department  RG/MDR-001/III/2021
#
#                        Business Area/Objective/Activity  \
# 0     Memberikan layanan 3PL (Third Party Logistics)...
# 1     Memberikan layanan 3PL (Third Party Logistics)...
# 2     Memberikan layanan 3PL (Third Party Logistics)...
# 3     Memberikan layanan 3PL (Third Party Logistics)...
# ...

# %%
csa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3179 entries, 0 to 3178
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Departemen                        3179 non-null   object
#  1   Source Data Process               3179 non-null   object
#  2   Business Area/Objective/Activity  3179 non-null   object
#  3   Risk/Event                        3179 non-null   object
#  4   Type                              3179 non-null   object
#  5   Detail                            3179 non-null   object
#  6   To Reduce                         3179 non-null   object
#  7   D                                 3179 non-null   int64
#  8   I                                 3179 non-null   int64
#  9   M                                 3179 non-null   int64
#  10  E                                 3179 non-null   int64
# ...

# %%
csa.D.value_counts()
# Out:
# 2    2325
# 3     722
# 1     132
# Name: D, dtype: int64

# %%
csa.I.value_counts()
# Out:
# 2    2113
# 3     889
# 1     177
# Name: I, dtype: int64

# %%
csa.M.value_counts()
# Out:
# 2    2441
# 1     453
# 3     284
# 0       1
# Name: M, dtype: int64

# %%
csa.E.value_counts()
# Out:
# 2    1829
# 1    1066
# 3     266
# 0      18
# Name: E, dtype: int64

# %%
csa['Type '].value_counts()
# Out:
# Prosedur Kerja                  1092
# Sistem IT                        582
# Komitmen Terhadap Kompetensi     525
# Kebijakan                        377
# Komunikasi                       319
# Dokumen                          216
# SDM                               48
# Jangka Waktu                      13
# Shared Values                      5
# Sistme IT                          2
# Name: Type , dtype: int64

# %%
csa['To Reduce'].value_counts()
# Out:
# Likelihood             2294
# Likelihood & Impact     834
# Impact                   51
# Name: To Reduce, dtype: int64

# %%
pd.crosstab(csa['Type '],csa['Scale'])
# Out:
# Scale                         Effective  Marginally Effective  \
# Type
# Dokumen                               6                    29
# Jangka Waktu                          0                     0
# Kebijakan                             0                     4
# Komitmen Terhadap Kompetensi          0                    42
# Komunikasi                            0                    34
# Prosedur Kerja                       55                   250
# SDM                                   0                     1
# Shared Values                         0                     0
# Sistem IT                           176                    72
# Sistme IT                             0                     0
#
# Scale                         Moderately Effective  Not Effective  \
# Type
# Dokumen                                        147              0
# Jangka Waktu                                     7              0
# Kebijakan                                      362              0
# ...

# %%
fig = px.histogram(csa, x="D",nbins = 20,color_discrete_sequence = ['darkred'])
fig.show()

# %%
fig = px.histogram(csa, x="I",nbins = 20,color_discrete_sequence = ['navy'])
fig.show()

# %%
fig = px.histogram(csa, x="M",nbins = 20,color_discrete_sequence = ['darkorange'])
fig.show()

# %%
fig = px.histogram(csa, x="E",nbins = 20,color_discrete_sequence = ['gold'])
fig.show()

# %%
label=csa['Type '].value_counts().index
count=csa['Type '].value_counts().values

fig = px.pie(count, values=count, names=label, title='PERSENTASE TIPE KONTROL')
fig.show()

# %%
fig = px.histogram(csa,x="Type ", color="Scale").update_xaxes(categoryorder="total descending")
fig.show()

# %%
px.histogram(csa, x='Type ', color="Scale", barmode='group').update_xaxes(categoryorder="total ascending")

# %%
label=csa['To Reduce'].value_counts().index
count=csa['To Reduce'].value_counts().values

fig = px.pie(count, values=count, names=label, title='PERSENTASE EFEKTIVITAS KONTROL')
fig.show()

# %%
px.histogram(csa, x='Source Data Process', color="Total", barmode='group')
