# %%
# charge pengiriman berdasarkan berat paket

berat_paket = int(input("Berat paket (Kg): "))

# jika berat kurang dari 50Kg maka pengiriman dapat dilakukan dengan tarif 8000 per Kg
# jika berat lebih dari 50Kg maka biaya kirim ditambah charga 500000
# jika berat lebih dari 120Kg maka tidak dapat dilakukan pengiriman

surcharge = 500000
bayar = berat_paket*8000

if int(berat_paket) < 50:
    print("Pengiriman paket segera dilakukan")  
    print("Total yang harus dibayar: Rp %s" % bayar)
    print("Terima kasih sudah mengirim paket lewat JNE")
    print("Kirim paket? JNE aja! JNE Connecting Happiness!")
if int(berat_paket) >= 50 and int(berat_paket) < 120:
    bayar = bayar + surcharge
    print("Pengiriman paket segera dilakukan")    
    print("Total yang harus dibayar: Rp %s" % bayar)
    print("Terima kasih sudah mengirim paket lewat JNE")
    print("Kirim paket? JNE aja! JNE Connecting Happiness!")
if int(berat_paket) >= 120: 
    print("Maaf ya, pengiriman tidak dapat dilakukan " )
    print("Kirim paket? JNE aja! JNE Connecting Happiness!")
# Out:
# Berat paket (Kg):  60
# Pengiriman paket segera dilakukan
# Total yang harus dibayar: Rp 980000
# Terima kasih sudah mengirim paket lewat JNE
# Kirim paket? JNE aja! JNE Connecting Happiness!

# %%
berat_paket = int(input("Berat paket(Kg):"))
tarif = 8000
biaya_pengiriman = berat_paket * 8000

if berat_paket < 50:
    print("Pengiriman paket segera dilakukan")
    print("Total yang harus dibayar: Rp", biaya_pengiriman)
   
elif berat_paket >= 50 and berat_paket <= 120 :
    print("Pengiriman paket segera dilakukan")
    print("Total yang harus dibayar: Rp", biaya_pengiriman + 500000)
    
elif berat_paket > 120:
    print("Maaf ya, pengiriman tidak dapat dilakukan")

print("Terima kasih sudah mengirim paket lewat JNE")
print("Kirim paket? JNE aja! JNE Connecting Happiness!")
# Out:
# Berat paket(Kg): 130
# Maaf ya, pengiriman tidak dapat dilakukan
# Terima kasih sudah mengirim paket lewat JNE
# Kirim paket? JNE aja! JNE Connecting Happiness!

# %%
# Remunerasi HRD PT Ntin Cerah Cemerlang Glowing Sepanjang Masa

grade = int(input("Grade : "))
masa_kerja = int(input("Masa_Kerja : "))

if int(grade) <= 1 and masa_kerja <= 2:
    print ("Grade Anda 1 (Staff) dengan masa kerja kurang dari 2 tahun ")
    print("Gaji Anda = Rp 3,5jt ") 
if int(grade) <= 1 and masa_kerja > 2:
    print ("Grade Anda 1 (staff) dengan masa kerja lebih dari 2 tahun ")
    print("Gaji Anda = Rp 4jt ")  
if int(grade) > 1 and int(grade) <= 2 and masa_kerja <=3:
    print ("Grade Anda 2 (head) dengan masa kerja kurang dari 3 tahun ")
    print("Gaji Anda = Rp 4,5jt ")  
if int(grade) > 1 and int(grade) <= 2 and masa_kerja >3:
    print ("Grade Anda 2 (head) dengan masa kerja lebih dari 3 tahun ")
    print("Gaji Anda = Rp 5jt ") 
if int(grade) > 2 and int(grade) <= 3 and masa_kerja <=5:
    print ("Grade Anda 3 (dept.head) dengan masa kerja kurang dari 5 tahun ")
    print("Gaji Anda = Rp 10jt ")  
if int(grade) > 2 and int(grade) <= 3 and masa_kerja >5:
    print ("Grade Anda 3 (dept.head) dengan masa kerja lebih dari 5 tahun ")
    print("Gaji Anda = Rp 15jt ")    
if int (grade) > 3:
    print("Data tidak sesuai! Resign aja dari PT Ntin Cerah Cemerlang Glowing Sepanjang Masa! ")
# Out:
# Grade :  4
# Masa_Kerja :  4
# Data tidak sesuai! Resign aja dari PT Ntin Cerah Cemerlang Glowing Sepanjang Masa!
