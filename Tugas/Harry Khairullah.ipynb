# %%
# menentukan berat kiriman

berat = int(input("Inputkan berat kiriman: "))

if berat >= 120:
       
   # hitung kiriman
   total = int(berat) * 9000   
         
   Keterangan = "Kiriman tidak bisa dikirim" 
   print("perkilo Rp.9.000,-")

   # cetak struk
   print("Total yang harus dibayar: Rp %s" % total)
    
elif berat >= 50:
   
   # hitung kiriman
   total = int(berat) * 9000  
   bayar = int(total) + 500000
         
   Keterangan = "Kiriman dikenai charge Rp. 500.000,-"
   print("perkilo Rp.9.000,-")

   # cetak struk
   print("Total yang harus dibayar: Rp %s" % bayar)
    
    
else:
   
   # hitung kiriman
   total = int(berat) * 9000   
         
   Keterangan = "Kiriman bisa dikirim" 
   print("perkilo Rp.9.000,-")

   # cetak struk
   print("Total yang harus dibayar: Rp %s" % total)

print("Keterangan: %s" % Keterangan)
# Out:
# Inputkan berat kiriman:  30
# perkilo Rp.9.000,-
# Total yang harus dibayar: Rp 270000
# Keterangan: Kiriman bisa dikirim

# %%
# menentukan standar gaji baru

grade = int(input("Inputkan grade: ")) 
masa_kerja = int(input("Inputkan masa kerja: "))

if grade == 3 and masa_kerja >= 5:
   print("Jabatan Dept. Head")
   print("Gaji yang diterima 15 Jt")
    
elif grade == 3 and masa_kerja <= 5:
   print("Jabatan Dept. Head")
   print("Gaji yang diterima 10 Jt")
    
elif grade == 2 and masa_kerja >= 3:
   print("Jabatan Head")
   print("Gaji yang diterima 5 Jt")
    
elif grade == 2 and masa_kerja <= 3:
   print("Jabatan Head")
   print("Gaji yang diterima 4.5 Jt")

elif grade == 1 and masa_kerja >= 2:
   print("Jabatan Staff")
   print("Gaji yang diterima 4 Jt")
    
elif grade == 1 and masa_kerja <= 2:
   print("Jabatan Staff")
   print("Gaji yang diterima 3.5 Jt")
    
else:
   print("Salah dan mohon di cek kembali")
# Out:
# Inputkan grade:  3
# Inputkan masa kerja:  9
# Jabatan Dept. Head
# Gaji yang diterima 15 Jt
