# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
omzet = pd.read_excel('Omset_Update.xlsx')
print(omzet)
# Out:
#        Unnamed: 0  PERIODE            REGION BRANCH_ID   BRANCH_NAME  \
# 0               0  2020-01             JTBNN    CB0032   CAB.MATARAM
# 1               1  2020-01             JTBNN    CB0032   CAB.MATARAM
# 2               2  2020-01             JTBNN    CB0032   CAB.MATARAM
# 3               3  2020-01             JTBNN    CB0032   CAB.MATARAM
# 4               4  2020-01             JTBNN    CB0032   CAB.MATARAM
# ...           ...      ...               ...       ...           ...
# 58053       58053  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
# 58054       58054  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
# 58055       58055  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
# 58056       58056  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
# 58057       58057  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
#
#       SERVICES_CODE ZONE_DESTINATION  JUMLAH_AWB  JUMLAH_WEIGHT  JUMLAH_CASH  \
# ...

# %% [markdown]
# ## Tugas 1

# %%
omzet.head(8)
# Out:
#    Unnamed: 0  PERIODE REGION BRANCH_ID  BRANCH_NAME SERVICES_CODE  \
# 0           0  2020-01  JTBNN    CB0032  CAB.MATARAM           CML
# 1           1  2020-01  JTBNN    CB0032  CAB.MATARAM         CTC19
# 2           2  2020-01  JTBNN    CB0032  CAB.MATARAM         CTC19
# 3           3  2020-01  JTBNN    CB0032  CAB.MATARAM         CTC19
# 4           4  2020-01  JTBNN    CB0032  CAB.MATARAM         CTC19
# 5           5  2020-01  JTBNN    CB0032  CAB.MATARAM      CTCYES19
# 6           6  2020-01  JTBNN    CB0032  CAB.MATARAM      CTCYES19
# 7           7  2020-01  JTBNN    CB0032  CAB.MATARAM         JTR18
#
#   ZONE_DESTINATION  JUMLAH_AWB  JUMLAH_WEIGHT  JUMLAH_CASH  JUMLAH_CREDIT  \
# 0                A         106        306.114          0.0            0.0
# 1                A         584        581.538     290500.0      2656750.0
# 2                B          46         58.002     288250.0       102500.0
# ...

# %% [markdown]
# ## Tugas 2

# %%
omzet.shape
# Out:
# (58058, 14)

# %% [markdown]
# ## Tugas 3

# %%
omzet.dtypes
# Out:
# Unnamed: 0            int64
# PERIODE              object
# REGION               object
# BRANCH_ID            object
# BRANCH_NAME          object
# SERVICES_CODE        object
# ZONE_DESTINATION     object
# JUMLAH_AWB            int64
# JUMLAH_WEIGHT       float64
# JUMLAH_CASH         float64
# JUMLAH_CREDIT       float64
# JUMLAH_COD          float64
# JUMLAH_EPAY         float64
# TOTAL_OMZET         float64
# dtype: object

# %% [markdown]
# ## Tugas 4

# %%
omzet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58058 entries, 0 to 58057
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        58058 non-null  int64
#  1   PERIODE           58058 non-null  object
#  2   REGION            58058 non-null  object
#  3   BRANCH_ID         58058 non-null  object
#  4   BRANCH_NAME       58058 non-null  object
#  5   SERVICES_CODE     58058 non-null  object
#  6   ZONE_DESTINATION  57702 non-null  object
#  7   JUMLAH_AWB        58058 non-null  int64
#  8   JUMLAH_WEIGHT     58050 non-null  float64
#  9   JUMLAH_CASH       58058 non-null  float64
#  10  JUMLAH_CREDIT     58058 non-null  float64
#  11  JUMLAH_COD        58058 non-null  float64
#  12  JUMLAH_EPAY       58058 non-null  float64
#  13  TOTAL_OMZET       58058 non-null  float64
# dtypes: float64(6), int64(2), object(6)
# memory usage: 6.2+ MB

# %% [markdown]
# ## Tugas 5

# %%
omzet.round()
# Out:
#        Unnamed: 0  PERIODE            REGION BRANCH_ID   BRANCH_NAME  \
# 0               0  2020-01             JTBNN    CB0032   CAB.MATARAM
# 1               1  2020-01             JTBNN    CB0032   CAB.MATARAM
# 2               2  2020-01             JTBNN    CB0032   CAB.MATARAM
# 3               3  2020-01             JTBNN    CB0032   CAB.MATARAM
# 4               4  2020-01             JTBNN    CB0032   CAB.MATARAM
# ...           ...      ...               ...       ...           ...
# 58053       58053  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
# 58054       58054  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
# 58055       58055  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
# 58056       58056  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
# 58057       58057  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
#
#       SERVICES_CODE ZONE_DESTINATION  JUMLAH_AWB  JUMLAH_WEIGHT  JUMLAH_CASH  \
# ...

# %% [markdown]
# ## Tugas 6

# %%
omzet = pd.read_excel('Omset_Update.xlsx')
omzet[['BRANCH_NAME' , 'TOTAL_OMZET']]
# Out:
#         BRANCH_NAME  TOTAL_OMZET
# 0       CAB.MATARAM         0.00
# 1       CAB.MATARAM   2952500.00
# 2       CAB.MATARAM    390750.00
# 3       CAB.MATARAM    676000.00
# 4       CAB.MATARAM    224500.00
# ...             ...          ...
# 58053  CAB.MAKASSAR         0.00
# 58054  CAB.MAKASSAR   1333500.00
# 58055  CAB.MAKASSAR  35840458.50
# 58056  CAB.MAKASSAR  48319673.75
# 58057  CAB.MAKASSAR   1410970.00
#
# [58058 rows x 2 columns]

# %% [markdown]
# ## Tugas 7

# %%
q1_columns = omzet[["JUMLAH_CREDIT", "JUMLAH_EPAY"]]
omzet["TOTAL_VIRTUAL"] = q1_columns.sum(axis=1)
omzet
# Out:
#        Unnamed: 0  PERIODE            REGION BRANCH_ID   BRANCH_NAME  \
# 0               0  2020-01             JTBNN    CB0032   CAB.MATARAM
# 1               1  2020-01             JTBNN    CB0032   CAB.MATARAM
# 2               2  2020-01             JTBNN    CB0032   CAB.MATARAM
# 3               3  2020-01             JTBNN    CB0032   CAB.MATARAM
# 4               4  2020-01             JTBNN    CB0032   CAB.MATARAM
# ...           ...      ...               ...       ...           ...
# 58053       58053  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
# 58054       58054  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
# 58055       58055  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
# 58056       58056  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
# 58057       58057  2022-07  SULAWESI - PAPUA    CB0035  CAB.MAKASSAR
#
#       SERVICES_CODE ZONE_DESTINATION  JUMLAH_AWB  JUMLAH_WEIGHT  JUMLAH_CASH  \
# ...

# %% [markdown]
# ## Tugas 8

# %%
omzet.sort_values("TOTAL_OMZET",ascending=True)
# Out:
#        Unnamed: 0  PERIODE            REGION BRANCH_ID   BRANCH_NAME  \
# 13709       13709  2020-09             JTBNN    CB0032   CAB.MATARAM
# 55868       55868  2022-07             JTBNN    CB0032   CAB.MATARAM
# 48941       48941  2022-03             JTBNN    CB0011  CAB.SURABAYA
# 43068       43068  2022-01      SERBODETABEK    CB0055    CAB.BEKASI
# 10906       10906  2020-07  SULAWESI - PAPUA    CB0039   CAB.KENDARI
# ...           ...      ...               ...       ...           ...
# 28310       28310  2021-05           JAKARTA    CB0001    HO JAKARTA
# 24735       24735  2021-03           JAKARTA    CB0001    HO JAKARTA
# 19409       19409  2020-12           JAKARTA    CB0001    HO JAKARTA
# 17625       17625  2020-11           JAKARTA    CB0001    HO JAKARTA
# 26514       26514  2021-04           JAKARTA    CB0001    HO JAKARTA
#
#       SERVICES_CODE ZONE_DESTINATION  JUMLAH_AWB  JUMLAH_WEIGHT   JUMLAH_CASH  \
# ...

# %%
omzet.pivot_table(index='BRANCH_NAME', 
                  values='TOTAL_OMZET', 
                  aggfunc='mean')
# Out:
#                      TOTAL_OMZET
# BRANCH_NAME
# CAB.AMBON           8.046365e+06
# CAB.BALIKPAPAN      2.198573e+07
# CAB.BANDA ACEH      8.069640e+06
# CAB.BANDAR LAMPUNG  3.572601e+07
# CAB.BANDUNG         4.277243e+08
# ...                          ...
# CAB.TEGAL           2.084024e+07
# CAB.TERNATE         8.054036e+06
# CAB.TIMIKA          3.720298e+06
# CAB.YOGYAKARTA      1.056231e+08
# HO JAKARTA          1.441932e+09
#
# [62 rows x 1 columns]
